# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lmfit.models import ExpressionModel

# %%
print("w2w experiment:")
the = (
    pd
    .read_excel('Data/parameters_He_Ne (reformatted).xlsx', sheet_name='Ne.0.0.5 w2w')
    .set_index(['dataset', 'phi (deg)'])
)
the
# Out:
# w2w experiment:
#                    photon (eV)     beta1     beta2     beta3     beta4  \
# dataset phi (deg)
# good1   0                 15.9 -0.006823 -0.178463  0.653422  0.965976
#         45                15.9  0.532410 -0.178216  0.951622  0.965931
#         90                15.9  0.760045 -0.178210  0.692528  0.965849
#         135               15.9  0.542795 -0.178445  0.027862  0.965780
#         180               15.9  0.007803 -0.178780 -0.653181  0.965764
#         225               15.9 -0.531597 -0.179023 -0.951604  0.965807
#         270               15.9 -0.759664 -0.179125 -0.691393  0.968269
#         315               15.9 -0.541898 -0.178804 -0.027551  0.965956
# good2   0                 14.3 -0.110180 -0.589441  0.408326  0.219918
#         45                14.3  0.290733 -0.588047  0.308652  0.219469
#         90                14.3  0.521729 -0.588039  0.027341  0.219373
#         135               14.3  0.447289 -0.588174 -0.270000  0.219265
# ...

# %%
print("w2w experiment (mean):")
the.groupby('dataset')[['beta2', 'beta4']].mean()
# Out:
# w2w experiment (mean):
#             beta2     beta4
# dataset
# good1   -0.178633  0.966166
# good2   -0.588438  0.219405
# good3    0.578244 -0.185540
# good4   -0.007279  0.695788

# %%
print("wonly experiment:")
pd.read_excel('Data/parameters_He_Ne (reformatted).xlsx', sheet_name='Ne.0.0.5 wonly')
# Out:
# wonly experiment:
#   dataset  photon (eV)     beta1     beta2     beta3     beta4
# 0   good1         15.9  0.000372 -0.491972  0.000208  1.468979
# 1   good2         14.3  0.000108 -0.802973 -0.000043  0.287946
# 2   good3         19.1 -0.000899  0.502074 -0.000330 -0.345162
# 3   good4         15.9  0.000376 -0.491347  0.000210  1.468849

# %%
dataset = 'good1'
keys = ['beta1', 'beta3', 'beta1m3']

model = ExpressionModel('amp * cos(freq * x - shift) + offset')
model.set_param_hint('amp', value=1, min=0)
model.set_param_hint('freq', value=1, vary=False)
model.set_param_hint('shift', value=np.pi/2, min=-np.pi, max=3*np.pi)
model.set_param_hint('offset', value=0)

df = the.loc[dataset]
plt.figure()
for k, prop in zip(keys, plt.rcParams['axes.prop_cycle']):
    fitted = model.fit(df[k], x=df.index/180*np.pi)
    print(k)
    print(fitted.fit_report())

    th = np.linspace(0, 2*np.pi, 361)
    plt.plot(df.index/180*np.pi, df[k], '.--', **prop)
    plt.plot(th, fitted.eval(x=th), **prop)
plt.show()
# Out:
# beta1
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 17
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 1.3689e-07
#     reduced chi-square = 2.7378e-08
#     Akaike info crit   = -137.068199
#     Bayesian info crit = -136.829875
# [[Variables]]
#     amp:     0.75980258 +/- 8.2732e-05 (0.01%) (init = 1)
#     freq:    1 (fixed)
#     shift:   1.58042191 +/- 1.0889e-04 (0.01%) (init = 1.570796)
#     offset:  3.8374e-04 +/- 5.8500e-05 (15.24%) (init = 0)
#
# beta3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 6.3148e-07
#     reduced chi-square = 1.2630e-07
#     Akaike info crit   = -124.837129
#     Bayesian info crit = -124.598805
# [[Variables]]
#     amp:     0.95182653 +/- 1.7769e-04 (0.02%) (init = 1)
# ...

# %%
dataset = 'good2'
keys = ['beta1', 'beta3', 'beta1m3']

model = ExpressionModel('amp * cos(freq * x - shift) + offset')
model.set_param_hint('amp', value=1, min=0)
model.set_param_hint('freq', value=1, vary=False)
model.set_param_hint('shift', value=np.pi/2, min=-np.pi, max=3*np.pi)
model.set_param_hint('offset', value=0)

df = the.loc[dataset]
plt.figure()
for k, prop in zip(keys, plt.rcParams['axes.prop_cycle']):
    fitted = model.fit(df[k], x=df.index/180*np.pi)
    print(k)
    print(fitted.fit_report())

    th = np.linspace(0, 2*np.pi, 361)
    plt.plot(df.index/180*np.pi, df[k], '.--', **prop)
    plt.plot(th, fitted.eval(x=th), **prop)
plt.show()
# Out:
# beta1
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 3.6120e-08
#     reduced chi-square = 7.2240e-09
#     Akaike info crit   = -147.726861
#     Bayesian info crit = -147.488536
# [[Variables]]
#     amp:     0.53306534 +/- 4.2497e-05 (0.01%) (init = 1)
#     freq:    1 (fixed)
#     shift:   1.77987529 +/- 7.9722e-05 (0.00%) (init = 1.570796)
#     offset:  3.1299e-04 +/- 3.0050e-05 (9.60%) (init = 0)
#
# beta3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 29
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 4.4650e-07
#     reduced chi-square = 8.9299e-08
#     Akaike info crit   = -127.610207
#     Bayesian info crit = -127.371882
# [[Variables]]
#     amp:     0.40988565 +/- 1.4941e-04 (0.04%) (init = 1)
# ...

# %%
dataset = 'good3'
keys = ['beta1', 'beta3', 'beta1m3']

model = ExpressionModel('amp * cos(freq * x - shift) + offset')
model.set_param_hint('amp', value=1, min=0)
model.set_param_hint('freq', value=1, vary=False)
model.set_param_hint('shift', value=np.pi/2, min=-np.pi, max=3*np.pi)
model.set_param_hint('offset', value=0)

df = the.loc[dataset]
plt.figure()
for k, prop in zip(keys, plt.rcParams['axes.prop_cycle']):
    fitted = model.fit(df[k], x=df.index/180*np.pi)
    print(k)
    print(fitted.fit_report())

    th = np.linspace(0, 2*np.pi, 361)
    plt.plot(df.index/180*np.pi, df[k], '.--', **prop)
    plt.plot(th, fitted.eval(x=th), **prop)
plt.show()
# Out:
# beta1
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 17
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 1.2172e-06
#     reduced chi-square = 2.4345e-07
#     Akaike info crit   = -119.586907
#     Bayesian info crit = -119.348583
# [[Variables]]
#     amp:     1.13419328 +/- 2.4670e-04 (0.02%) (init = 1)
#     freq:    1 (fixed)
#     shift:   1.57591947 +/- 2.1751e-04 (0.01%) (init = 1.570796)
#     offset: -0.00100581 +/- 1.7445e-04 (17.34%) (init = 0)
#
# beta3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 5.8110e-08
#     reduced chi-square = 1.1622e-08
#     Akaike info crit   = -143.922996
#     Bayesian info crit = -143.684671
# [[Variables]]
#     amp:     0.48913411 +/- 5.3903e-05 (0.01%) (init = 1)
# ...

# %%
dataset = 'good4'
keys = ['beta1', 'beta3', 'beta1m3']

model = ExpressionModel('amp * cos(freq * x - shift) + offset')
model.set_param_hint('amp', value=1, min=0)
model.set_param_hint('freq', value=1, vary=False)
model.set_param_hint('shift', value=np.pi/2, min=-np.pi, max=3*np.pi)
model.set_param_hint('offset', value=0)

df = the.loc[dataset]
plt.figure()
for k, prop in zip(keys, plt.rcParams['axes.prop_cycle']):
    fitted = model.fit(df[k], x=df.index/180*np.pi)
    print(k)
    print(fitted.fit_report())

    th = np.linspace(0, 2*np.pi, 361)
    plt.plot(df.index/180*np.pi, df[k], '.--', **prop)
    plt.plot(th, fitted.eval(x=th), **prop)
plt.show()
# Out:
# beta1
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 17
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 1.2780e-07
#     reduced chi-square = 2.5560e-08
#     Akaike info crit   = -137.617782
#     Bayesian info crit = -137.379458
# [[Variables]]
#     amp:     0.79184780 +/- 7.9938e-05 (0.01%) (init = 1)
#     freq:    1 (fixed)
#     shift:   1.57942150 +/- 1.0095e-04 (0.01%) (init = 1.570796)
#     offset:  3.9433e-04 +/- 5.6525e-05 (14.33%) (init = 0)
#
# beta3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 4.2334e-07
#     reduced chi-square = 8.4668e-08
#     Akaike info crit   = -128.036261
#     Bayesian info crit = -127.797936
# [[Variables]]
#     amp:     0.98951290 +/- 1.4549e-04 (0.01%) (init = 1)
# ...
