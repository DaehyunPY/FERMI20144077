# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
exp = pd.read_excel('Data/neon_eta_negp_gauss3.xlsx', sheet_name='eta')
exp['photon'] = exp['photon (eV)']
exp['weight'] = 1 / exp['eta_f−d_err'] ** 2
exp['weighted_dph'] = exp['weight'] * exp['eta_f−d']

grp = exp[['photon', 'weighted_dph', 'weight']].groupby('photon').sum()
grp['ke'] = 2*grp.index - 24.58738880
grp['dph'] = grp['weighted_dph'] / grp['weight']
grp['dph_err'] = 1 / grp['weight'] ** 0.5
grp = grp[['ke', 'dph', 'dph_err']]
grp
# Out:
#                ke       dph   dph_err
# photon
# 14.3     4.012611  1.667223  0.027393
# 15.9     7.212611  1.452253  0.043198
# 19.1    13.612611  1.402048  0.014170

# %%
def err_operadd(a, b):
    return (a**2 + b**2) ** 0.5


dff = pd.DataFrame({
    'ke': (grp['ke'].values[1:] + grp['ke'].values[:-1]) / 2,
    'ke_err': np.diff(grp['ke']) / 2,
    'dt': np.diff(grp['dph']) / np.diff(grp['ke']) * 24.1888432651 / 0.0367493,
    'dt_err': (err_operadd(grp['dph_err'].values[1:], grp['dph_err'].values[:-1])
               / np.diff(grp['ke']) * 24.1888432651 / 0.0367493),
})
dff
# Out:
#           ke  ke_err         dt     dt_err
# 0   5.612611     1.6 -44.217493  10.521446
# 1  10.412611     3.2  -5.163374   4.675657

# %%
the = pd.read_excel('Data/the_neon_elena.xlsx', sheet_name='20180215')
the['dph'] = (the['phase_diff (rad)']-np.pi) % (2*np.pi)
the['ke'] = 2*the['w_photon (eV)'] - 24.58738880
the['dt'] = np.gradient(the['dph'], the['ke']) * 24.1888432651 / 0.0367493
the = the[['ke', 'dph', 'dt']][the['ke']<14]
the
# Out:
#           ke       dph         dt
# 0   4.412611  1.430073 -81.355015
# 1   5.412611  1.306473 -67.260462
# 2   6.412611  1.225699 -46.453836
# 3   7.412611  1.165321 -35.943489
# 4   8.412611  1.116484 -29.936162
# 5   9.412611  1.074359 -26.001589
# 6  10.412611  1.037477 -22.886357
# 7  11.412611  1.004818 -20.309137
# 8  12.412611  0.975767 -18.137357
# 9  13.412611  0.949707 -16.179179

# %%
the = pd.read_excel('Data/the_neon_elena.xlsx')
the['ke'] = 2*the['w_photon (eV)'] - 24.58738880
the['dph_scatt'] = the['phase_scatt (rad)'] % (2*np.pi)
the['dt_scatt'] = np.gradient(the['dph_scatt'], the['ke']) * 24.1888432651 / 0.0367493
the['dph_res'] = the['phase_res (rad)'] % (2*np.pi)
the['dt_res'] = np.gradient(the['dph_res'], the['ke']) * 24.1888432651 / 0.0367493
the = the[the['ke']<15]
the
# Out:
#     w_photon (eV)  phase_scatt (rad)  phase_res (rad)         ke  dph_scatt  \
# 0            14.0           1.949366         1.946309   3.412611   1.949366
# 1            14.2           1.937456         1.934258   3.812611   1.937456
# 2            14.4           1.925231         1.921889   4.212611   1.925231
# 3            14.6           1.912687         1.909200   4.612611   1.912687
# 4            14.8           1.899855         1.896218   5.012611   1.899855
# 5            15.0           1.886792         1.882998   5.412611   1.886792
# 6            15.2           1.873575         1.869714   5.812611   1.873575
# 7            15.4           1.860299         1.856276   6.212611   1.860299
# 8            15.6           1.847074         1.842849   6.612611   1.847074
# 9            15.8           1.834021         1.829509   7.012611   1.834021
# 10           16.0           1.821274         1.816518   7.412611   1.821274
# 11           16.2           1.808971         1.803976   7.812611   1.808971
# 12           16.4           1.797262         1.792003   8.212611   1.797262
# 13           16.6           1.786320         1.780767   8.612611   1.786320
# 14           16.8           1.775952         1.770071   9.012611   1.775952
# 15           17.0           1.766070         1.759821   9.412611   1.766070
# 16           17.2           1.756720         1.750053   9.812611   1.756720
# 17           17.4           1.748070         1.740940  10.212611   1.748070
# 18           17.6           1.739675         1.731995  10.612611   1.739675
# 19           17.8           1.731724         1.723402  11.012611   1.731724
# 20           18.0           1.724178         1.715098  11.412611   1.724178
# 21           18.2           1.717036         1.707047  11.812611   1.717036
# 22           18.4           1.710432         1.699331  12.212611   1.710432
# 23           18.6           1.703991         1.691500  12.612611   1.703991
# 24           18.8           1.697873         1.683596  13.012611   1.697873
# 25           19.0           1.692061         1.675404  13.412611   1.692061
# 26           19.2           1.686701         1.666709  13.812611   1.686701
# 27           19.4           1.681510         1.656426  14.212611   1.681510
# 28           19.6           1.676542         1.643060  14.612611   1.676542
#
#      dt_scatt   dph_res     dt_res
# 0  -19.598451  1.946309 -19.831173
# 1  -19.857953  1.934258 -20.091985
# 2  -20.379134  1.921889 -20.616874
# 3  -20.877774  1.909200 -21.121644
# 4  -21.305353  1.896218 -21.558030
# 5  -21.622669  1.882998 -21.806382
# 6  -21.797732  1.869714 -21.986147
# 7  -21.804206  1.856276 -22.103601
# 8  -21.620226  1.842849 -22.022515
# 9  -21.227506  1.829509 -21.664337
# 10 -20.610644  1.816518 -21.007981
# 11 -19.755851  1.803976 -20.170336
# 12 -18.636599  1.792003 -19.095666
# 13 -17.533251  1.780767 -18.044356
# 14 -16.660422  1.770071 -17.233186
# 15 -15.823499  1.759821 -16.470222
# 16 -14.810575  1.750053 -15.534963
# 17 -14.023633  1.740940 -14.857344
# 18 -13.448808  1.731995 -14.429666
# 19 -12.750820  1.723402 -13.902737
# 20 -12.084104  1.715098 -13.456328
# 21 -11.309210  1.707047 -12.972186
# 22 -10.733380  1.699331 -12.791473
# 23 -10.333643  1.691500 -12.946072
# 24  -9.815457  1.683596 -13.243149
# 25  -9.191710  1.675404 -13.894612
# 26  -8.681256  1.666709 -15.614916
# 27  -8.358653  1.656426 -19.457695
# 28  -7.969659  1.643060 -28.495311

# %%
plt.style.use('My Poster.mplstyle')
plt.figure(figsize=(15, 6.5))
plt.subplot(121)
plt.xlabel(r'Photoelectron kinetic energy (eV)')
plt.ylabel('Phase difference (rad)\n'
           r'${\eta_f}_{\rm,two} - {\eta_d}_{\rm,one}$')
plt.plot(the['ke'], the['dph_scatt'], '-', label='Calculation')
plt.errorbar(grp['ke'], grp['dph'],
             yerr=grp['dph_err'],
             fmt='o',
             label='This exp.')
plt.xlim(3, 15)
plt.grid(True)

plt.subplot(122)
plt.xlabel(r'Photoelectron kinetic energy (eV)')
plt.ylabel('Time delay difference (as)\n'
           r'${\tau_f}_{\rm,two} - {\tau_d}_{\rm,one}$')
plt.plot(the['ke'], the['dt_scatt'], '-', label='Calculation')
plt.errorbar(dff['ke'], dff['dt'],
             xerr=dff['ke_err'], yerr=dff['dt_err'],
             fmt=',',
             label='This exp.')
plt.xlim(3, 15)
plt.grid(True)

plt.legend(loc='lower right', shadow=True)
plt.tight_layout()
plt.savefig('Figures/Phase shifts (poster).pdf')
plt.show()
