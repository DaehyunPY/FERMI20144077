# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lmfit.models import ExpressionModel

# %%
print("w2w experiment:")
the = (
    pd
    .read_excel('Data/parameters_He_Ne (reformatted).xlsx', sheet_name='Ne.1.0.8 w2w')
    .set_index(['dataset', 'phi (deg)'])
)
the
# Out:
# w2w experiment:
#                    photon (eV)     beta1     beta2     beta3     beta4  \
# dataset phi (deg)
# good1   0                 15.9  0.073316 -0.143320  0.730613  1.276849
#         45                15.9  0.529341 -0.142719  1.092683  1.276957
#         90                15.9  0.675881 -0.142768  0.815157  1.276741
#         135               15.9  0.427175 -0.143445  0.060544  1.276325
#         180               15.9 -0.071268 -0.144352 -0.729424  1.275955
#         225               15.9 -0.527545 -0.144948 -1.091925  1.275852
#         270               15.9 -0.674194 -0.144887 -0.814306  1.276072
#         315               15.9 -0.425236 -0.144214 -0.059260  1.276484
# good2   0                 14.3 -0.071449 -0.526892  0.406765  0.224457
#         45                14.3  0.325740 -0.526970  0.310760  0.224475
#         90                14.3  0.532005 -0.526965  0.032691  0.224516
#         135               14.3  0.426504 -0.526879 -0.264524  0.224552
#         180               14.3  0.071075 -0.526765 -0.406770  0.224563
#         225               14.3 -0.326063 -0.526692 -0.310750  0.224544
#         270               14.3 -0.532306 -0.526698 -0.032721  0.224507
#         315               14.3 -0.426856 -0.526780  0.264479  0.224471
# good3   0                 19.1  0.147219  0.662347  0.665999  0.366496
#         45                19.1  0.944743  0.662458  0.822451  0.366682
#         90                19.1  1.186732  0.662706  0.495236  0.366522
#         135               19.1  0.731518  0.662941 -0.122827  0.366105
#         180               19.1 -0.152043  0.663031 -0.668668  0.365674
#         225               19.1 -0.946462  0.662928 -0.823687  0.365485
#         270               19.1 -1.188574  0.662688 -0.498087  0.365651
#         315               19.1 -0.736464  0.662445  0.118543  0.366070
# good4   0                 15.9  0.082826  0.017063  0.813038  0.915811
#         45                15.9  0.590129  0.017675  1.214704  0.916009
#         90                15.9  0.752489  0.017607  0.905364  0.915834
#         135               15.9  0.474867  0.016884  0.066078  0.915381
#         180               15.9 -0.080365  0.015937 -0.811908  0.914921
#         225               15.9 -0.588025  0.015334 -1.214127  0.914729
#         270               15.9 -0.750476  0.015421 -0.904571  0.914914
#         315               15.9 -0.472497  0.016135 -0.064732  0.915360
#
#                     beta1m3
# dataset phi (deg)
# good1   0         -1.022604
#         45        -1.109683
#         90        -0.546855
#         135        0.336359
#         180        1.022867
#         225        1.110343
#         270        0.547265
#         315       -0.336346
# good2   0         -0.681596
#         45        -0.140400
#         90         0.482969
#         135        0.823290
#         180        0.681230
#         225        0.140063
#         270       -0.483224
#         315       -0.823575
# good3   0         -0.851779
#         45        -0.288934
#         90         0.443879
#         135        0.915757
#         180        0.850959
#         225        0.289069
#         270       -0.441444
#         315       -0.914278
# good4   0         -1.136730
#         45        -1.231927
#         90        -0.605558
#         135        0.375750
#         180        1.137498
#         225        1.233166
#         270        0.606380
#         315       -0.375398

# %%
print("w2w experiment (mean):")
the.groupby('dataset')[['beta2', 'beta4']].mean()
# Out:
# w2w experiment (mean):
#             beta2     beta4
# dataset
# good1   -0.143832  1.276404
# good2   -0.526830  0.224511
# good3    0.662693  0.366086
# good4    0.016507  0.915370

# %%
print("wonly experiment:")
pd.read_excel('Data/parameters_He_Ne (reformatted).xlsx', sheet_name='Ne.0.0.5 wonly')
# Out:
# wonly experiment:
#   dataset  photon (eV)     beta1     beta2     beta3     beta4
# 0   good1         15.9  0.000372 -0.491972  0.000208  1.468979
# 1   good2         14.3  0.000108 -0.802973 -0.000043  0.287946
# 2   good3         19.1 -0.000899  0.502074 -0.000330 -0.345162
# 3   good4         15.9  0.000376 -0.491347  0.000210  1.468849

# %%
dataset = 'good1'
keys = ['beta1', 'beta3', 'beta1m3']

model = ExpressionModel('amp * cos(freq * x - shift) + offset')
model.set_param_hint('amp', value=1, min=0)
model.set_param_hint('freq', value=1, vary=False)
model.set_param_hint('shift', value=np.pi/2, min=-np.pi, max=3*np.pi)
model.set_param_hint('offset', value=0)

df = the.loc[dataset]
plt.figure()
for k, prop in zip(keys, plt.rcParams['axes.prop_cycle']):
    fitted = model.fit(df[k], x=df.index/180*np.pi)
    print(k)
    print(fitted.fit_report())

    th = np.linspace(0, 2*np.pi, 361)
    plt.plot(df.index/180*np.pi, df[k], '.--', **prop)
    plt.plot(th, fitted.eval(x=th), **prop)
plt.show()
# Out:
# beta1
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 3.7687e-08
#     reduced chi-square = 7.5374e-09
#     Akaike info crit   = -147.387164
#     Bayesian info crit = -147.148839
# [[Variables]]
#     amp:     0.67889792 +/- 4.3409e-05 (0.01%) (init = 1)
#     freq:    1 (fixed)
#     shift:   1.46410908 +/- 6.3940e-05 (0.00%) (init = 1.570796)
#     offset:  9.3349e-04 +/- 3.0695e-05 (3.29%) (init = 0)
#
# beta3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 9.7848e-08
#     reduced chi-square = 1.9570e-08
#     Akaike info crit   = -139.754376
#     Bayesian info crit = -139.516051
# [[Variables]]
#     amp:     1.09394489 +/- 6.9946e-05 (0.01%) (init = 1)
#     freq:    1 (fixed)
#     shift:   0.84018307 +/- 6.3939e-05 (0.01%) (init = 1.570796)
#     offset:  5.1009e-04 +/- 4.9459e-05 (9.70%) (init = 0)
#
# beta1m3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 1.1000e-07
#     reduced chi-square = 2.1999e-08
#     Akaike info crit   = -138.818172
#     Bayesian info crit = -138.579847
# [[Variables]]
#     amp:     1.15985444 +/- 7.4160e-05 (0.01%) (init = 1)
#     freq:    1 (fixed)
#     shift:   3.63276839 +/- 6.3939e-05 (0.00%) (init = 1.570796)
#     offset:  1.6837e-04 +/- 5.2439e-05 (31.15%) (init = 0)

# %%
dataset = 'good2'
keys = ['beta1', 'beta3', 'beta1m3']

model = ExpressionModel('amp * cos(freq * x - shift) + offset')
model.set_param_hint('amp', value=1, min=0)
model.set_param_hint('freq', value=1, vary=False)
model.set_param_hint('shift', value=np.pi/2, min=-np.pi, max=3*np.pi)
model.set_param_hint('offset', value=0)

df = the.loc[dataset]
plt.figure()
for k, prop in zip(keys, plt.rcParams['axes.prop_cycle']):
    fitted = model.fit(df[k], x=df.index/180*np.pi)
    print(k)
    print(fitted.fit_report())

    th = np.linspace(0, 2*np.pi, 361)
    plt.plot(df.index/180*np.pi, df[k], '.--', **prop)
    plt.plot(th, fitted.eval(x=th), **prop)
plt.show()
# Out:
# beta1
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 1.5415e-09
#     reduced chi-square = 3.0831e-10
#     Akaike info crit   = -172.959413
#     Bayesian info crit = -172.721089
# [[Variables]]
#     amp:     0.53690568 +/- 8.7793e-06 (0.00%) (init = 1)
#     freq:    1 (fixed)
#     shift:   1.70391557 +/- 1.6352e-05 (0.00%) (init = 1.570796)
#     offset: -1.6875e-04 +/- 6.2079e-06 (3.68%) (init = 0)
#
# beta3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 31
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 8.8977e-10
#     reduced chi-square = 1.7795e-10
#     Akaike info crit   = -177.356025
#     Bayesian info crit = -177.117700
# [[Variables]]
#     amp:     0.40808040 +/- 6.6700e-06 (0.00%) (init = 1)
#     freq:    1 (fixed)
#     shift:   0.08023251 +/- 1.6345e-05 (0.02%) (init = 1.570796)
#     offset: -8.8796e-06 +/- 4.7159e-06 (53.11%) (init = 0)
#
# beta1m3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 3.7296e-09
#     reduced chi-square = 7.4592e-10
#     Akaike info crit   = -165.891293
#     Bayesian info crit = -165.652968
# [[Variables]]
#     amp:     0.83528779 +/- 1.3656e-05 (0.00%) (init = 1)
#     freq:    1 (fixed)
#     shift:   2.52487696 +/- 1.6349e-05 (0.00%) (init = 1.570796)
#     offset: -1.5543e-04 +/- 9.6561e-06 (6.21%) (init = 0)

# %%
dataset = 'good3'
keys = ['beta1', 'beta3', 'beta1m3']

model = ExpressionModel('amp * cos(freq * x - shift) + offset')
model.set_param_hint('amp', value=1, min=0)
model.set_param_hint('freq', value=1, vary=False)
model.set_param_hint('shift', value=np.pi/2, min=-np.pi, max=3*np.pi)
model.set_param_hint('offset', value=0)

df = the.loc[dataset]
plt.figure()
for k, prop in zip(keys, plt.rcParams['axes.prop_cycle']):
    fitted = model.fit(df[k], x=df.index/180*np.pi)
    print(k)
    print(fitted.fit_report())

    th = np.linspace(0, 2*np.pi, 361)
    plt.plot(df.index/180*np.pi, df[k], '.--', **prop)
    plt.plot(th, fitted.eval(x=th), **prop)
plt.show()
# Out:
# beta1
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 17
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 4.8268e-06
#     reduced chi-square = 9.6536e-07
#     Akaike info crit   = -108.566145
#     Bayesian info crit = -108.327820
# [[Variables]]
#     amp:     1.19704126 +/- 4.9126e-04 (0.04%) (init = 1)
#     freq:    1 (fixed)
#     shift:   1.44546716 +/- 4.1040e-04 (0.03%) (init = 1.570796)
#     offset: -0.00166645 +/- 3.4738e-04 (20.85%) (init = 0)
#
# beta3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 2.3307e-06
#     reduced chi-square = 4.6613e-07
#     Akaike info crit   = -114.390404
#     Bayesian info crit = -114.152079
# [[Variables]]
#     amp:     0.83186950 +/- 3.4137e-04 (0.04%) (init = 1)
#     freq:    1 (fixed)
#     shift:   0.63980868 +/- 4.1036e-04 (0.06%) (init = 1.570796)
#     offset: -0.00138006 +/- 2.4138e-04 (17.49%) (init = 0)
#
# beta1m3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 3.1007e-06
#     reduced chi-square = 6.2014e-07
#     Akaike info crit   = -112.106599
#     Bayesian info crit = -111.868274
# [[Variables]]
#     amp:     0.95957194 +/- 3.9374e-04 (0.04%) (init = 1)
#     freq:    1 (fixed)
#     shift:   2.66212070 +/- 4.1033e-04 (0.02%) (init = 1.570796)
#     offset:  4.0365e-04 +/- 2.7842e-04 (68.98%) (init = 0)

# %%
dataset = 'good4'
keys = ['beta1', 'beta3', 'beta1m3']

model = ExpressionModel('amp * cos(freq * x - shift) + offset')
model.set_param_hint('amp', value=1, min=0)
model.set_param_hint('freq', value=1, vary=False)
model.set_param_hint('shift', value=np.pi/2, min=-np.pi, max=3*np.pi)
model.set_param_hint('offset', value=0)

df = the.loc[dataset]
plt.figure()
for k, prop in zip(keys, plt.rcParams['axes.prop_cycle']):
    fitted = model.fit(df[k], x=df.index/180*np.pi)
    print(k)
    print(fitted.fit_report())

    th = np.linspace(0, 2*np.pi, 361)
    plt.plot(df.index/180*np.pi, df[k], '.--', **prop)
    plt.plot(th, fitted.eval(x=th), **prop)
plt.show()
# Out:
# beta1
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 17
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 6.7938e-08
#     reduced chi-square = 1.3588e-08
#     Akaike info crit   = -142.672871
#     Bayesian info crit = -142.434547
# [[Variables]]
#     amp:     0.75589994 +/- 5.8283e-05 (0.01%) (init = 1)
#     freq:    1 (fixed)
#     shift:   1.46264001 +/- 7.7104e-05 (0.01%) (init = 1.570796)
#     offset:  0.00111855 +/- 4.1212e-05 (3.68%) (init = 0)
#
# beta3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 1.7582e-07
#     reduced chi-square = 3.5165e-08
#     Akaike info crit   = -135.065768
#     Bayesian info crit = -134.827443
# [[Variables]]
#     amp:     1.21617455 +/- 9.3762e-05 (0.01%) (init = 1)
#     freq:    1 (fixed)
#     shift:   0.83920287 +/- 7.7095e-05 (0.01%) (init = 1.570796)
#     offset:  4.8078e-04 +/- 6.6299e-05 (13.79%) (init = 0)
#
# beta1m3
# [[Model]]
#     Model(_eval)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 38
#     # data points      = 8
#     # variables        = 3
#     chi-square         = 1.9734e-07
#     reduced chi-square = 3.9467e-08
#     Akaike info crit   = -134.142392
#     Bayesian info crit = -133.904068
# [[Variables]]
#     amp:     1.28849769 +/- 9.9332e-05 (0.01%) (init = 1)
#     freq:    1 (fixed)
#     shift:   3.63121406 +/- 7.7091e-05 (0.00%) (init = 1.570796)
#     offset:  3.9738e-04 +/- 7.0237e-05 (17.68%) (init = 0)
